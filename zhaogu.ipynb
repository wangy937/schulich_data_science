# %%
import os
import re
import time
import requests
import openpyxl
import pandas as pd
from typing import List, Dict, Tuple
from datetime import date

# ========= 可调参数 =========
# 关键词：仅用“招股说明书”作服务端检索，以减少请求量
KEYWORDS = ["招股说明书"]
# 可选：额外关键词（留空，避免扩大服务器端召回导致跑得慢）
EXTRA_KWS: List[str] = []

# 时间范围（起止含边界）
DATE_BEGIN = "2000-01-01"
DATE_END   = date.today().strftime("%Y-%m-%d")

# 输出目录 / 输入映射表
output_dir   = os.path.expanduser("~/Desktop/cninfo_output")
os.makedirs(output_dir, exist_ok=True)
mapping_file = os.path.expanduser("~/Desktop/正股映射结果.xlsx")

# 输出文件（列名仍沿用“链接”）
OUT_XLSX = os.path.join(output_dir, "招股说明书链接_选取公司【招股】.xlsx")
SHEET    = "招股说明书"

# 市场/板块保持你的原设定
MARKETS = ["szse", "shse"]
PLATES  = ["", "sz", "szmb", "szcy", "sh", "shmb", "shkcp", "bj"]

# 显式排除的干扰词
EXCLUDE_KWS = [
    # 语言/摘要/附录/公告类
    "英文", "英文版", "Annual", "annual", "Summary", "summary", "摘要", "摘要版",
    "附录", "公告", "之更正公告", "更正公告",
    # 各类“确认意见”
    "确认意见", "监事对招股说明书", "全体监事对招股说明书",
    "控股股东、实际控制人", "实际控制人及一致行动人", "一致行动人对招股说明书", "发行人监事对招股说明书",
    # GDR/瑞交所相关
    "GDR", "瑞士交易所", "瑞士证券交易所", "价格区间确定", "批准的公告",
    # 非IPO：增发
    "公开增发", "增发",
    # 其他不需要
    "取消", "已取消", "提示性公告", "更名提示", "B股", "H股"
]

# ========= 工具函数 =========
_SPACE_RE = re.compile(r"[\s\u00A0\u3000]+")
def norm(s: str) -> str:
    return _SPACE_RE.sub("", str(s or "").strip())

def any_kw_in(text: str, kws: List[str]) -> bool:
    t = norm(text)
    return any(norm(k) in t for k in kws if k)

# 宽松年份提取：优先从标题中抽取，兜底用公告时间
_TITLE_YEAR_PATS = [
    re.compile(r"(20\d{2})\s*年?\s*度?\s*招\s*股\s*说\s*明\s*书"),
    re.compile(r"(20\d{2})\s*年?\s*招\s*股\s*说\s*明\s*书"),
    re.compile(r"(19\d{2}|20\d{2})")  # 兜底：任何四位年份
]

def extract_year_from_title(title: str) -> str:
    t = norm(title)
    for pat in _TITLE_YEAR_PATS:
        m = pat.search(t)
        if m:
            return m.group(1)
    return ""

def year_from_timestamp_ms(ts: int) -> str:
    try:
        return time.strftime("%Y", time.localtime(int(ts)/1000))
    except Exception:
        return ""

# ========= 关键筛选：只保留 IPO 正文版招股书 =========
def is_target_prospectus(title: str) -> bool:
    """
    仅保留【招股说明书（IPO正文）】：
      - 必含“招股说明书”
      - 显式排除：摘要/附录/公告/确认意见/监事/全体监事/控股股东/一致行动人/GDR/瑞士(交易所/证券交易所)/价格区间确定/批准的公告/增发
      - IPO 判断：
          * 若标题含“首次公开发行”→ 明确 IPO，保留
          * 若标题含“增发/公开增发”→ 非IPO，剔除
          * 其余情况（早期标题常仅写“招股说明书”）→ 默认按 IPO 处理
    """
    t = norm(title)
    if "招股说明书" not in t:
        return False
    if any_kw_in(t, EXCLUDE_KWS):
        return False
    # 出现“增发”则一律排除
    if ("增发" in t) or ("公开增发" in t):
        return False
    # 明确写“首次公开发行”的直接保留；否则默认也按IPO处理（兼容老标题）
    return True

# ========= 权重：修订/更正优先，时间近优先 =========
def ann_weight(it: Dict) -> Tuple[int, int]:
    """
    对同公司多条正文：修正/更正/更新/修订 加分；同级按时间近优先
    """
    title = norm(it.get("announcementTitle", ""))
    w = 100
    if ("修正稿" in title) or ("更正" in title) or ("更新" in title) or ("修订" in title):
        w += 10
    try:
        ts = int(it.get("announcementTime", 0))
    except Exception:
        ts = 0
    return (w, ts)

# ========= 调接口 =========
def get_report(page_num: int, date_range: str, column: str, plate: str, searchkey: str="") -> requests.Response:
    url = "http://www.cninfo.com.cn/new/hisAnnouncement/query"
    payload = {
        "pageNum":   page_num,
        "pageSize":  30,
        "column":    column,       # szse/shse
        "tabName":   "fulltext",
        "category":  "",           # 置空：用 searchkey
        "plate":     plate,
        "searchkey": searchkey,    # 招股说明书
        "secid":     "",
        "trade":     "",
        "seDate":    date_range,   # 2000-01-01~YYYY-MM-DD
        "sortName":  "code",
        "sortType":  "asc",
        "isHLtitle": "false"
    }
    headers = {
        "Accept":           "*/*",
        "Accept-Language":  "zh-CN,zh;q=0.9",
        "Content-Type":     "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin":           "http://www.cninfo.com.cn",
        "Referer":          "http://www.cninfo.com.cn/new/commonUrl/pageOfSearch?url=disclosure/list/search",
        "User-Agent":       "Mozilla/5.0",
        "X-Requested-With": "XMLHttpRequest"
    }
    return requests.post(url, data=payload, headers=headers, timeout=15)

def download_for_segments(segments: List[str], column: str, plate: str, searchkey: str) -> List[Dict]:
    """
    分段分页拉取；在本地做“正文IPO招股书”过滤 + 去重（secCode, adjunctUrl）
    """
    all_ann: List[Dict] = []
    seen = set()
    for date_range in segments:
        try:
            total = get_report(1, date_range, column, plate, searchkey).json().get("totalpages", 0)
        except Exception:
            continue
        if total <= 0:
            continue

        page = 1
        while page <= total:
            for _ in range(3):  # 重试三次
                try:
                    resp = get_report(page, date_range, column, plate, searchkey)
                    resp.raise_for_status()
                    anns = resp.json().get("announcements", []) or []
                    for x in anns:
                        title = x.get("announcementTitle", "") or ""
                        if not is_target_prospectus(title):
                            continue
                        key = (str(x.get("secCode", "")), str(x.get("adjunctUrl", "")))
                        if key in seen:
                            continue
                        seen.add(key)
                        all_ann.append(x)
                    break
                except Exception:
                    time.sleep(1.0)
            page += 1
    return all_ann

def collect_all_prospectus() -> List[Dict]:
    """
    将 2000-01-01 ~ 今天 按年切片，关键词仅用“招股说明书”，避免多关键词造成请求量暴涨
    """
    y_begin = int(DATE_BEGIN[:4])
    y_end   = int(DATE_END[:4])
    segments: List[str] = []
    for y in range(y_begin, y_end + 1):
        seg_start = f"{y}-01-01" if y > y_begin else DATE_BEGIN
        seg_end   = f"{y}-12-31" if y < y_end   else DATE_END
        segments.append(f"{seg_start}~{seg_end}")

    raw: List[Dict] = []
    for col in MARKETS:
        for pl in PLATES:
            raw.extend(download_for_segments(segments, col, pl, "招股说明书"))
    return raw

# ========= 选公司 & 去重取优（公司维度，仅一条） =========
def filter_latest_per_company(anns: List[Dict], valid_secs: set) -> List[Dict]:
    """
    仅保留映射公司；每家公司只取一条：按（修订优先 + 时间近）择最新 IPO 正文招股书
    """
    best: Dict[str, Dict] = {}
    for it in anns:
        sec = str(it.get("secCode", ""))
        if sec not in valid_secs:
            continue
        if (sec not in best) or (ann_weight(it) > ann_weight(best[sec])):
            best[sec] = it
    return list(best.values())

# ========= 写 Excel：每家公司一行 =========
def write_selected_excel(anns: List[Dict]) -> None:
    """
    列顺序与“年报版”一致：可转债代码、可转债名称、公司代码、公司简称、标题、年份、链接
    每家公司仅输出 1 行（最新版 IPO 招股说明书正文）；无命中则空行
    """
    df_map = pd.read_excel(mapping_file, dtype=str).fillna("")
    df_map["sec_no_suf"] = df_map["正股代码"].str.split(".").str[0]

    # (secCode) -> 记录
    ann_by_sec: Dict[str, Dict] = {}
    for it in anns:
        sec = str(it.get("secCode", ""))
        if sec and (sec not in ann_by_sec or ann_weight(it) > ann_weight(ann_by_sec[sec])):
            ann_by_sec[sec] = it

    wb = openpyxl.Workbook()
    ws = wb.active
    ws.title = SHEET
    ws.append(["可转债代码","可转债名称","公司代码","公司简称","标题","年份","链接"])

    for _, row in df_map.iterrows():
        bond_code = row.get("代码", "")
        bond_name = row.get("名称", "")
        sec       = row.get("sec_no_suf", "")
        comp_name = row.get("正股名称", "")

        it = ann_by_sec.get(sec)
        if it:
            raw_title = re.sub(r"<.*?>","", it.get("announcementTitle","")).replace("：","")
            title = f"《{raw_title}》"
            yr  = extract_year_from_title(raw_title) or year_from_timestamp_ms(it.get("announcementTime", 0))
            url = f"http://static.cninfo.com.cn/{it.get('adjunctUrl','')}"
            ws.append([bond_code, bond_name, sec, comp_name, title, yr, url])
        else:
            ws.append([bond_code, bond_name, sec, comp_name, "", "", ""])

    wb.save(OUT_XLSX)
    print(f"✅ 已输出：{OUT_XLSX}（工作表：{SHEET}）")

# ========= 主流程 =========
def main():
    # 1) 公司集合
    df_map = pd.read_excel(mapping_file, dtype=str).fillna("")
    valid_secs = set(df_map["正股代码"].str.split(".").str[0].tolist())

    # 2) 拉取 + 粗过滤（仅“招股说明书”关键字）
    raw = collect_all_prospectus()

    # 3) 仅保留映射公司 + 去重取优（公司维度，仅一条）
    picked = filter_latest_per_company(raw, valid_secs)

    # 4) 导出（列顺序与年报版一致）
    write_selected_excel(picked)

    print("---- 招股说明书检索完成 ----")

if __name__ == "__main__":
    main()
# Out:
# ✅ 已输出：/Users/sam/Desktop/cninfo_output/招股说明书链接_选取公司【招股】.xlsx（工作表：招股说明书）
# ---- 招股说明书检索完成 ----

# %%
import pandas as pd
import requests
import os
import re
import logging
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed

# ========== 日志 ==========
logging.basicConfig(level=logging.INFO, format='[%(asctime)s] %(message)s')

def log(msg: str):
    print(f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] {msg}")

# ========== 参数 ==========
BASE_DIR    = os.path.expanduser("~/Desktop/cninfo_output")
EXCEL_FILE  = os.path.join(BASE_DIR, "招股说明书链接_选取公司【招股】.xlsx")
SHEET_NAME  = "招股说明书"  # 与采集脚本保持一致
PDF_DIR     = os.path.join(BASE_DIR, "pdf_prospectus_latest")
MAX_WORKERS = 16
os.makedirs(PDF_DIR, exist_ok=True)

# ========== 工具 ==========
def norm_code(x: str) -> str:
    """把类似 600000 / 600000.0 / '600000 ' 统一成 6 位字符串"""
    s = str(x).strip()
    s = s.split('.')[0]
    s = re.sub(r'\D', '', s)
    return s.zfill(6) if s else ""

def is_pdf_response(resp: requests.Response) -> bool:
    ct = (resp.headers.get("Content-Type") or "").lower()
    return ("pdf" in ct) or resp.content.startswith(b"%PDF")

def safe_name(s: str) -> str:
    return re.sub(r'[\\/:*?"<>|]', '', s)

# 直接使用一个 Session 以重用连接，提高下载效率
SESSION = requests.Session()
SESSION.headers.update({
    "User-Agent": "Mozilla/5.0",
    "Referer": "http://www.cninfo.com.cn/",
})

def download_pdf(record):
    code, name, year, title, url = record
    # 文件名：代码_简称_年份（或标题年缺失则留空）
    base = f"{norm_code(code)}_{str(name).strip()}_{str(int(year)) if str(year).isdigit() else str(year).strip()}"
    base = base.strip("_")
    path = os.path.join(PDF_DIR, f"{safe_name(base)}.pdf")

    if os.path.exists(path) and os.path.getsize(path) > 0:
        log(f"Exists, skip: {path}")
        return

    try:
        resp = SESSION.get(url, timeout=25, allow_redirects=True)
        if resp.status_code == 200 and is_pdf_response(resp):
            with open(path, 'wb') as f:
                f.write(resp.content)
            log(f"Downloaded: {path}")
        else:
            log(f"Failed ({resp.status_code}) or not PDF: {url}")
    except Exception as e:
        log(f"Error downloading {url}: {e}")

# ========== 主流程 ==========

def main():
    log(f"Reading Excel: {EXCEL_FILE}")
    if not os.path.exists(EXCEL_FILE):
        log("Excel file not found. 请检查路径和文件名是否为『招股说明书链接_选取公司【招股】.xlsx』。")
        return

    # 读取“招股说明书”sheet
    df = pd.read_excel(EXCEL_FILE, sheet_name=SHEET_NAME, dtype=str)
    df.columns = [str(c).strip() for c in df.columns]

    # 丢弃无链接/空白行（采集脚本对未命中的公司会留空）
    if "链接" not in df.columns:
        log("列名『链接』未找到，请确认采集脚本输出列是否未被修改。")
        return

    df = df.dropna(subset=["链接"])  # 只保留有链接的

    # 有些行年份为空，下载不依赖年份，但文件名里尽量带上
    if "年份" not in df.columns:
        df["年份"] = ""

    records = [
        (
            df.at[i, "公司代码"],
            df.at[i, "公司简称"],
            (str(df.at[i, "年份"]).split('.')[0] if pd.notna(df.at[i, "年份"]) else ""),
            df.at[i, "标题"],
            str(df.at[i, "链接"]).strip(),
        )
        for i in df.index
        if str(df.at[i, "链接"]).strip()
    ]

    log(f"Found {len(records)} prospectus records (latest per company). Start downloading...")

    start = datetime.now()
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(download_pdf, rec) for rec in records]
        for _ in as_completed(futures):
            pass
    elapsed = (datetime.now() - start).total_seconds()
    log(f"All downloads completed in {elapsed:.2f}s. PDFs saved to: {PDF_DIR}")

if __name__ == '__main__':
    main()
# Out:
# [2025-08-28 18:07:15] Reading Excel: /Users/sam/Desktop/cninfo_output/招股说明书链接_选取公司【招股】.xlsx
# [2025-08-28 18:07:15] Found 370 prospectus records (latest per company). Start downloading...
# [2025-08-28 18:07:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600496_精工钢构_2002.pdf
# [2025-08-28 18:07:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600370_三房巷_2003.pdf
# [2025-08-28 18:07:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600531_豫光金铅_2002.pdf
# [2025-08-28 18:07:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600419_天润乳业_2001.pdf
# [2025-08-28 18:07:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600481_双良节能_2003.pdf
# [2025-08-28 18:07:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600438_通威股份_2004.pdf
# [2025-08-28 18:07:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600577_精达股份_2002.pdf
# [2025-08-28 18:07:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600461_洪城环境_2004.pdf
# [2025-08-28 18:07:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600521_华海药业_2003.pdf
# [2025-08-28 18:07:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600029_南方航空_2003.pdf
# [2025-08-28 18:07:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600933_爱柯迪_2017.pdf
# [2025-08-28 18:07:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605068_明新旭腾_2020.pdf
# [2025-08-28 18:07:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605116_奥锐特_2020.pdf
# [2025-08-28 18:07:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605166_聚合顺_2020.pdf
# [2025-08-28 18:07:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601515_东峰集团_2012.pdf
# [2025-08-28 18:07:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605166_聚合顺_2020.pdf
# [2025-08-28 18:07:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605088_冠盛股份_2020.pdf
# [2025-08-28 18:07:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600909_华安证券_2016.pdf
# [2025-08-28 18:07:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600939_重庆建工_2017.pdf
# [2025-08-28 18:07:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601860_紫金银行_2018.pdf
# [2025-08-28 18:07:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605222_起帆电缆_2020.pdf
# [2025-08-28 18:07:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605007_五洲特纸_2020.pdf
# [2025-08-28 18:07:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601619_嘉泽新能_2017.pdf
# [2025-08-28 18:07:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605138_盛泰集团_2021.pdf
# [2025-08-28 18:07:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605366_宏柏新材_2020.pdf
# [2025-08-28 18:07:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601636_旗滨集团_2011.pdf
# [2025-08-28 18:07:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600926_杭州银行_2016.pdf
# [2025-08-28 18:07:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601633_长城汽车_2011.pdf
# [2025-08-28 18:07:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601229_上海银行_2016.pdf
# [2025-08-28 18:07:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601009_南京银行_2007.pdf
# [2025-08-28 18:07:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601016_节能风电_2014.pdf
# [2025-08-28 18:07:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601012_隆基绿能_2012.pdf
# [2025-08-28 18:07:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601231_环旭电子_2012.pdf
# [2025-08-28 18:07:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605177_东亚药业_2020.pdf
# [2025-08-28 18:07:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/605358_立昂微_2020.pdf
# [2025-08-28 18:07:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601166_兴业银行_2007.pdf
# [2025-08-28 18:07:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601137_博威合金_2011.pdf
# [2025-08-28 18:07:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601865_福莱特_2019.pdf
# [2025-08-28 18:07:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601158_重庆水务_2010.pdf
# [2025-08-28 18:07:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601366_利群股份_2017.pdf
# [2025-08-28 18:07:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601609_金田股份_2020.pdf
# [2025-08-28 18:07:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601208_东材科技_2011.pdf
# [2025-08-28 18:07:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601330_绿色动力_2018.pdf
# [2025-08-28 18:07:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603898_好莱客_2015.pdf
# [2025-08-28 18:07:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603368_柳药集团_2014.pdf
# [2025-08-28 18:07:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603113_金能科技_2017.pdf
# [2025-08-28 18:07:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601128_常熟银行_2016.pdf
# [2025-08-28 18:07:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603861_白云电器_2016.pdf
# [2025-08-28 18:07:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603890_春秋电子_2017.pdf
# [2025-08-28 18:07:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601686_友发集团_2020.pdf
# [2025-08-28 18:07:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603707_健友股份_2017.pdf
# [2025-08-28 18:07:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/600903_贵州燃气_2017.pdf
# [2025-08-28 18:07:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601609_金田股份_2020.pdf
# [2025-08-28 18:07:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603089_正裕工业_2017.pdf
# [2025-08-28 18:07:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603336_宏辉果蔬_2016.pdf
# [2025-08-28 18:07:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603679_华体科技_2017.pdf
# [2025-08-28 18:07:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601108_财通证券_2017.pdf
# [2025-08-28 18:07:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603108_润达医疗_2015.pdf
# [2025-08-28 18:07:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603377_ST东时_2016.pdf
# [2025-08-28 18:07:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603233_大参林_2017.pdf
# [2025-08-28 18:07:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603716_塞力医疗_2016.pdf
# [2025-08-28 18:07:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603660_苏州科达_2016.pdf
# [2025-08-28 18:07:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603708_家家悦_2016.pdf
# [2025-08-28 18:07:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603912_佳力图_2017.pdf
# [2025-08-28 18:07:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603579_荣泰健康_2016.pdf
# [2025-08-28 18:07:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603776_永安行_2017.pdf
# [2025-08-28 18:07:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603669_灵康药业_2015.pdf
# [2025-08-28 18:07:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603538_美诺华_2017.pdf
# [2025-08-28 18:07:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603966_法兰泰克_2017.pdf
# [2025-08-28 18:07:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603131_上海沪工_2016.pdf
# [2025-08-28 18:07:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603650_彤程新材_2018.pdf
# [2025-08-28 18:07:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603225_新凤鸣_2017.pdf
# [2025-08-28 18:07:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603608_天创时尚_2016.pdf
# [2025-08-28 18:07:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603979_金诚信_2015.pdf
# [2025-08-28 18:07:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/601778_晶科科技_2020.pdf
# [2025-08-28 18:07:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603877_太平鸟_2016.pdf
# [2025-08-28 18:07:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603208_江山欧派_2017.pdf
# [2025-08-28 18:07:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603501_豪威集团_2017.pdf
# [2025-08-28 18:07:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603976_正川股份_2017.pdf
# [2025-08-28 18:07:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603982_泉峰汽车_2019.pdf
# [2025-08-28 18:07:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603689_皖天然气_2016.pdf
# [2025-08-28 18:07:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603685_晨丰科技_2017.pdf
# [2025-08-28 18:07:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603638_艾迪精密_2017.pdf
# [2025-08-28 18:07:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603477_巨星农牧_2017.pdf
# [2025-08-28 18:07:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603733_仙鹤股份_2018.pdf
# [2025-08-28 18:07:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603605_珀莱雅_2017.pdf
# [2025-08-28 18:07:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603799_华友钴业_2015.pdf
# [2025-08-28 18:07:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603112_华翔股份_2020.pdf
# [2025-08-28 18:07:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603058_永吉股份_2016.pdf
# [2025-08-28 18:07:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603055_台华新材_2017.pdf
# [2025-08-28 18:07:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603916_苏博特_2017.pdf
# [2025-08-28 18:07:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603995_甬金股份_2019.pdf
# [2025-08-28 18:07:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603585_苏利股份_2016.pdf
# [2025-08-28 18:07:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603992_松霖科技_2019.pdf
# [2025-08-28 18:07:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603601_再升科技_2015.pdf
# [2025-08-28 18:07:44] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603890_春秋电子_2017.pdf
# [2025-08-28 18:07:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603355_莱克电气_2015.pdf
# [2025-08-28 18:07:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603486_科沃斯_2018.pdf
# [2025-08-28 18:07:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603810_丰山集团_2018.pdf
# [2025-08-28 18:07:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603535_嘉诚国际_2017.pdf
# [2025-08-28 18:07:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603568_伟明环保_2015.pdf
# [2025-08-28 18:07:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603833_欧派家居_2017.pdf
# [2025-08-28 18:07:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603327_福蓉科技_2019.pdf
# [2025-08-28 18:07:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603180_金牌家居_2017.pdf
# [2025-08-28 18:07:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603681_永冠新材_2019.pdf
# [2025-08-28 18:07:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603896_寿仙谷_2017.pdf
# [2025-08-28 18:07:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603901_永创智能_2015.pdf
# [2025-08-28 18:07:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603609_禾丰股份_2014.pdf
# [2025-08-28 18:07:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603186_华正新材_2016.pdf
# [2025-08-28 18:07:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603466_风语筑_2017.pdf
# [2025-08-28 18:07:47] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603568_伟明环保_2015.pdf
# [2025-08-28 18:07:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603757_大元泵业_2017.pdf
# [2025-08-28 18:07:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603306_华懋科技_2014.pdf
# [2025-08-28 18:07:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603228_景旺电子_2016.pdf
# [2025-08-28 18:07:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603051_鹿山新材_2022.pdf
# [2025-08-28 18:07:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603179_新泉股份_2017.pdf
# [2025-08-28 18:07:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603713_密尔克卫_2018.pdf
# [2025-08-28 18:07:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603730_岱美股份_2017.pdf
# [2025-08-28 18:07:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603165_荣晟环保_2017.pdf
# [2025-08-28 18:07:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603878_武进不锈_2016.pdf
# [2025-08-28 18:07:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603018_华设集团_2014.pdf
# [2025-08-28 18:07:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603867_新化股份_2019.pdf
# [2025-08-28 18:07:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603305_旭升集团_2017.pdf
# [2025-08-28 18:07:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603628_清源股份_2016.pdf
# [2025-08-28 18:07:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603067_振华股份_2016.pdf
# [2025-08-28 18:07:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603060_国检集团_2016.pdf
# [2025-08-28 18:07:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603809_豪能股份_2017.pdf
# [2025-08-28 18:07:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603829_洛凯股份_2017.pdf
# [2025-08-28 18:07:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603937_丽岛新材_2017.pdf
# [2025-08-28 18:07:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603220_中贝通信_2018.pdf
# [2025-08-28 18:07:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603801_志邦家居_2017.pdf
# [2025-08-28 18:07:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603289_泰瑞机器_2017.pdf
# [2025-08-28 18:07:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688388_嘉元科技_2019.pdf
# [2025-08-28 18:07:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603939_益丰药房_2015.pdf
# [2025-08-28 18:07:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688179_阿拉丁_2020.pdf
# [2025-08-28 18:07:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688116_天奈科技_2019.pdf
# [2025-08-28 18:07:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688001_华兴源创_2019.pdf
# [2025-08-28 18:07:55] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603197_保隆科技_2017.pdf
# [2025-08-28 18:07:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688321_微芯生物_2019.pdf
# [2025-08-28 18:07:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688026_洁特生物_2020.pdf
# [2025-08-28 18:07:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/603105_芯能科技_2018.pdf
# [2025-08-28 18:07:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688096_京源环保_2020.pdf
# [2025-08-28 18:07:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688186_广大特材_2020.pdf
# [2025-08-28 18:07:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688357_建龙微纳_2019.pdf
# [2025-08-28 18:07:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688166_博瑞医药_2019.pdf
# [2025-08-28 18:08:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688219_会通股份_2020.pdf
# [2025-08-28 18:08:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688268_华特气体_2019.pdf
# [2025-08-28 18:08:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688135_利扬芯片_2020.pdf
# [2025-08-28 18:08:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688398_赛特新材_2020.pdf
# [2025-08-28 18:08:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688516_奥特维_2020.pdf
# [2025-08-28 18:08:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688103_国力股份_2021.pdf
# [2025-08-28 18:08:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688002_睿创微纳_2019.pdf
# [2025-08-28 18:08:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688066_航天宏图_2019.pdf
# [2025-08-28 18:08:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688589_力合微_2020.pdf
# [2025-08-28 18:08:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688208_道通科技_2020.pdf
# [2025-08-28 18:08:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688223_晶科能源_2022.pdf
# [2025-08-28 18:08:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688292_浩瀚深度_2022.pdf
# [2025-08-28 18:08:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300545_联得装备_2016.pdf
# [2025-08-28 18:08:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688372_伟测科技_2022.pdf
# [2025-08-28 18:08:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688403_汇成股份_2022.pdf
# [2025-08-28 18:08:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688019_安集科技_2019.pdf
# [2025-08-28 18:08:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300190_维尔利_2011.pdf
# [2025-08-28 18:08:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300655_晶瑞电材_2017.pdf
# [2025-08-28 18:08:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688596_正帆科技_2020.pdf
# [2025-08-28 18:08:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688599_天合光能_2020.pdf
# [2025-08-28 18:08:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300265_通光线缆_2011.pdf
# [2025-08-28 18:08:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300677_英科医疗_2017.pdf
# [2025-08-28 18:08:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300231_银信科技_2011.pdf
# [2025-08-28 18:08:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300021_大禹节水_2009.pdf
# [2025-08-28 18:08:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688556_高测股份_2020.pdf
# [2025-08-28 18:08:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688711_宏微科技_2021.pdf
# [2025-08-28 18:08:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300511_雪榕生物_2016.pdf
# [2025-08-28 18:08:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688030_山石网科_2019.pdf
# [2025-08-28 18:08:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300608_思特奇_2017.pdf
# [2025-08-28 18:08:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300577_开润股份_2016.pdf
# [2025-08-28 18:08:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300424_航新科技_2015.pdf
# [2025-08-28 18:08:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300665_飞鹿股份_2017.pdf
# [2025-08-28 18:08:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300246_宝莱特_2011.pdf
# [2025-08-28 18:08:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300729_乐歌股份_2017.pdf
# [2025-08-28 18:08:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300016_北陆药业_2009.pdf
# [2025-08-28 18:08:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300298_三诺生物_2012.pdf
# [2025-08-28 18:08:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300482_万孚生物_2015.pdf
# [2025-08-28 18:08:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300429_强力新材_2015.pdf
# [2025-08-28 18:08:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300527_ST应急_2016.pdf
# [2025-08-28 18:08:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300196_长海股份_2011.pdf
# [2025-08-28 18:08:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300003_乐普医疗_2009.pdf
# [2025-08-28 18:08:09] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300517_海波重科_2016.pdf
# [2025-08-28 18:08:09] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300651_金陵体育_2017.pdf
# [2025-08-28 18:08:09] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300112_万讯自控_2010.pdf
# [2025-08-28 18:08:09] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300057_万顺新材_2010.pdf
# [2025-08-28 18:08:09] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300655_晶瑞电材_2017.pdf
# [2025-08-28 18:08:09] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300601_康泰生物_2017.pdf
# [2025-08-28 18:08:09] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300253_卫宁健康_2011.pdf
# [2025-08-28 18:08:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/688106_金宏气体_2020.pdf
# [2025-08-28 18:08:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300739_明阳电路_2018.pdf
# [2025-08-28 18:08:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300243_瑞丰高材_2011.pdf
# [2025-08-28 18:08:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300483_首华燃气_2015.pdf
# [2025-08-28 18:08:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300569_天能重工_2016.pdf
# [2025-08-28 18:08:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300791_仙乐健康_2019.pdf
# [2025-08-28 18:08:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300151_昌红科技_2010.pdf
# [2025-08-28 18:08:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300332_天壕能源_2012.pdf
# [2025-08-28 18:08:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300613_富瀚微_2017.pdf
# [2025-08-28 18:08:12] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300263_隆华科技_2011.pdf
# [2025-08-28 18:08:12] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300305_裕兴股份_2012.pdf
# [2025-08-28 18:08:13] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300673_佩蒂股份_2017.pdf
# [2025-08-28 18:08:13] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300529_健帆生物_2016.pdf
# [2025-08-28 18:08:13] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300707_威唐工业_2017.pdf
# [2025-08-28 18:08:13] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300738_奥飞数据_2018.pdf
# [2025-08-28 18:08:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300185_通裕重工_2011.pdf
# [2025-08-28 18:08:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300283_温州宏丰_2011.pdf
# [2025-08-28 18:08:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300692_中环环保_2017.pdf
# [2025-08-28 18:08:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300776_帝尔激光_2019.pdf
# [2025-08-28 18:08:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300406_九强生物_2014.pdf
# [2025-08-28 18:08:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300775_三角防务_2019.pdf
# [2025-08-28 18:08:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300486_东杰智能_2015.pdf
# [2025-08-28 18:08:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300224_正海磁材_2011.pdf
# [2025-08-28 18:08:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300779_惠城环保_2019.pdf
# [2025-08-28 18:08:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300798_锦鸡股份_2019.pdf
# [2025-08-28 18:08:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300258_精锻科技_2011.pdf
# [2025-08-28 18:08:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300891_惠云钛业_2020.pdf
# [2025-08-28 18:08:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300556_丝路视觉_2016.pdf
# [2025-08-28 18:08:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300401_花园生物_2014.pdf
# [2025-08-28 18:08:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300663_科蓝软件_2017.pdf
# [2025-08-28 18:08:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300850_新强联_2020.pdf
# [2025-08-28 18:08:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300876_蒙泰高新_2020.pdf
# [2025-08-28 18:08:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300037_新宙邦_2009.pdf
# [2025-08-28 18:08:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300567_精测电子_2016.pdf
# [2025-08-28 18:08:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300872_天阳科技_2020.pdf
# [2025-08-28 18:08:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300725_药石科技_2017.pdf
# [2025-08-28 18:08:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300853_申昊科技_2020.pdf
# [2025-08-28 18:08:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300605_恒锋信息_2017.pdf
# [2025-08-28 18:08:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300839_博汇股份_2020.pdf
# [2025-08-28 18:08:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300732_设研院_2017.pdf
# [2025-08-28 18:08:22] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300739_明阳电路_2018.pdf
# [2025-08-28 18:08:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300645_正元智慧_2017.pdf
# [2025-08-28 18:08:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300740_水羊股份_2018.pdf
# [2025-08-28 18:08:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300487_蓝晓科技_2015.pdf
# [2025-08-28 18:08:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300272_开能健康_2011.pdf
# [2025-08-28 18:08:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300501_海顺新材_2016.pdf
# [2025-08-28 18:08:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300787_海能实业_2019.pdf
# [2025-08-28 18:08:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300480_光力科技_2015.pdf
# [2025-08-28 18:08:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300900_广联航空_2020.pdf
# [2025-08-28 18:08:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300837_浙矿股份_2020.pdf
# [2025-08-28 18:08:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300869_康泰医学_2020.pdf
# [2025-08-28 18:08:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300121_阳谷华泰_2010.pdf
# [2025-08-28 18:08:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300452_山河药辅_2015.pdf
# [2025-08-28 18:08:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300644_南京聚隆_2018.pdf
# [2025-08-28 18:08:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300454_深信服_2018.pdf
# [2025-08-28 18:08:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301229_纽泰格_2022.pdf
# [2025-08-28 18:08:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301186_超达装备_2021.pdf
# [2025-08-28 18:08:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300239_东宝生物_2011.pdf
# [2025-08-28 18:08:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301098_金埔园林_2021.pdf
# [2025-08-28 18:08:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300829_金丹科技_2020.pdf
# [2025-08-28 18:08:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300737_科顺股份_2018.pdf
# [2025-08-28 18:08:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300062_中能电气_2010.pdf
# [2025-08-28 18:08:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301127_武汉天源_2021.pdf
# [2025-08-28 18:08:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300852_四会富仕_2020.pdf
# [2025-08-28 18:08:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300705_九典制药_2017.pdf
# [2025-08-28 18:08:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301266_宇邦新材_2022.pdf
# [2025-08-28 18:08:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301268_铭利达_2022.pdf
# [2025-08-28 18:08:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300428_立中集团_2015.pdf
# [2025-08-28 18:08:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300830_金现代_2020.pdf
# [2025-08-28 18:08:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301133_金钟股份_2021.pdf
# [2025-08-28 18:08:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300488_恒锋工具_2015.pdf
# [2025-08-28 18:08:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301188_力诺药包_2021.pdf
# [2025-08-28 18:08:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300358_楚天科技_2014.pdf
# [2025-08-28 18:08:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301069_凯盛新材_2021.pdf
# [2025-08-28 18:08:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301081_严牌股份_2021.pdf
# [2025-08-28 18:08:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301062_上海艾录_2021.pdf
# [2025-08-28 18:08:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300893_松原安全_2020.pdf
# [2025-08-28 18:08:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301193_家联科技_2021.pdf
# [2025-08-28 18:08:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301131_聚赛龙_2022.pdf
# [2025-08-28 18:08:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300553_集智股份_2016.pdf
# [2025-08-28 18:08:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300681_英搏尔_2017.pdf
# [2025-08-28 18:08:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300054_鼎龙股份_2010.pdf
# [2025-08-28 18:08:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300826_测绘股份_2020.pdf
# [2025-08-28 18:08:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002126_银轮股份_2007.pdf
# [2025-08-28 18:08:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300793_佳禾智能_2019.pdf
# [2025-08-28 18:08:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002091_江苏国泰_2006.pdf
# [2025-08-28 18:08:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300014_亿纬锂能_2009.pdf
# [2025-08-28 18:08:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301216_万凯新材_2022.pdf
# [2025-08-28 18:08:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300856_科思股份_2020.pdf
# [2025-08-28 18:08:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300890_翔丰华_2020.pdf
# [2025-08-28 18:08:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002887_绿茵生态_2017.pdf
# [2025-08-28 18:08:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002225_濮耐股份_2008.pdf
# [2025-08-28 18:08:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300870_欧陆通_2020.pdf
# [2025-08-28 18:08:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301053_远信工业_2021.pdf
# [2025-08-28 18:08:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002568_百润股份_2011.pdf
# [2025-08-28 18:08:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300351_永贵电器_2012.pdf
# [2025-08-28 18:08:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300337_银邦股份_2012.pdf
# [2025-08-28 18:08:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002534_西子洁能_2010.pdf
# [2025-08-28 18:08:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002833_弘亚数控_2016.pdf
# [2025-08-28 18:08:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002822_ST中装_2016.pdf
# [2025-08-28 18:08:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002381_双箭股份_2010.pdf
# [2025-08-28 18:08:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002895_川恒股份_2017.pdf
# [2025-08-28 18:08:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002398_垒知集团_2010.pdf
# [2025-08-28 18:08:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/301235_华康洁净_2022.pdf
# [2025-08-28 18:08:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002430_杭氧股份_2010.pdf
# [2025-08-28 18:08:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002798_帝欧家居_2016.pdf
# [2025-08-28 18:08:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002714_牧原股份_2014.pdf
# [2025-08-28 18:08:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/300911_亿田智能_2020.pdf
# [2025-08-28 18:08:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002918_蒙娜丽莎_2017.pdf
# [2025-08-28 18:08:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002455_百川股份_2010.pdf
# [2025-08-28 18:08:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002753_永东股份_2015.pdf
# [2025-08-28 18:08:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002891_中宠股份_2017.pdf
# [2025-08-28 18:08:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/003009_中天火箭_2020.pdf
# [2025-08-28 18:08:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002959_小熊电器_2019.pdf
# [2025-08-28 18:08:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002850_科达利_2017.pdf
# [2025-08-28 18:08:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002237_恒邦股份_2008.pdf
# [2025-08-28 18:08:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002698_博实股份_2012.pdf
# [2025-08-28 18:08:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002120_韵达股份_2007.pdf
# [2025-08-28 18:08:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002645_华宏科技_2011.pdf
# [2025-08-28 18:08:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002969_嘉美包装_2019.pdf
# [2025-08-28 18:08:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002709_天赐材料_2014.pdf
# [2025-08-28 18:08:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002540_亚太科技_2011.pdf
# [2025-08-28 18:08:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002459_晶澳科技_2010.pdf
# [2025-08-28 18:08:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002989_中天精装_2020.pdf
# [2025-08-28 18:08:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002998_优彩资源_2020.pdf
# [2025-08-28 18:08:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002111_威海广泰_2007.pdf
# [2025-08-28 18:08:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002996_顺博合金_2020.pdf
# [2025-08-28 18:08:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002135_东南网架_2007.pdf
# [2025-08-28 18:08:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002761_浙江建投_2015.pdf
# [2025-08-28 18:08:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002810_山东赫达_2016.pdf
# [2025-08-28 18:08:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002984_森麒麟_2020.pdf
# [2025-08-28 18:08:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002598_山东章鼓_2011.pdf
# [2025-08-28 18:08:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002982_湘佳股份_2020.pdf
# [2025-08-28 18:08:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/001288_运机集团_2021.pdf
# [2025-08-28 18:08:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/001283_豪鹏科技_2022.pdf
# [2025-08-28 18:08:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002600_领益智造_2011.pdf
# [2025-08-28 18:08:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002442_龙星科技_2010.pdf
# [2025-08-28 18:08:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002988_豪美新材_2020.pdf
# [2025-08-28 18:08:55] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002806_华锋股份_2016.pdf
# [2025-08-28 18:08:55] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002871_伟隆股份_2017.pdf
# [2025-08-28 18:08:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002809_红墙股份_2016.pdf
# [2025-08-28 18:08:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002382_蓝帆医疗_2010.pdf
# [2025-08-28 18:08:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/001317_三羊马_2021.pdf
# [2025-08-28 18:08:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002203_海亮股份_2008.pdf
# [2025-08-28 18:08:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002722_物产金轮_2014.pdf
# [2025-08-28 18:08:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002174_游族网络_2007.pdf
# [2025-08-28 18:08:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002171_楚江新材_2007.pdf
# [2025-08-28 18:08:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002228_合兴包装_2008.pdf
# [2025-08-28 18:08:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002605_姚记科技_2011.pdf
# [2025-08-28 18:08:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002022_科华生物_2004.pdf
# [2025-08-28 18:08:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002812_恩捷股份_2016.pdf
# [2025-08-28 18:08:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002436_兴森科技_2010.pdf
# [2025-08-28 18:08:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002921_联诚精密_2017.pdf
# [2025-08-28 18:08:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002067_景兴纸业_2006.pdf
# [2025-08-28 18:08:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/001269_欧晶科技_2022.pdf
# [2025-08-28 18:08:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002775_文科股份_2015.pdf
# [2025-08-28 18:08:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002877_智能自控_2017.pdf
# [2025-08-28 18:08:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002930_宏川智慧_2018.pdf
# [2025-08-28 18:08:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002815_崇达技术_2016.pdf
# [2025-08-28 18:08:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002726_龙大美食_2014.pdf
# [2025-08-28 18:09:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002557_洽洽食品_2011.pdf
# [2025-08-28 18:09:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002616_长青集团_2011.pdf
# [2025-08-28 18:09:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002949_华阳国际_2019.pdf
# [2025-08-28 18:09:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002475_立讯精密_2010.pdf
# [2025-08-28 18:09:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002734_利民股份_2015.pdf
# [2025-08-28 18:09:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002859_洁美科技_2017.pdf
# [2025-08-28 18:09:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002287_奇正藏药_2009.pdf
# [2025-08-28 18:09:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002958_青农商行_2019.pdf
# [2025-08-28 18:09:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002614_奥佳华_2011.pdf
# [2025-08-28 18:09:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002408_齐翔腾达_2010.pdf
# [2025-08-28 18:09:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002541_鸿路钢构_2011.pdf
# [2025-08-28 18:09:03,650] Connection pool is full, discarding connection: static.cninfo.com.cn. Connection pool size: 10
# [2025-08-28 18:09:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/003004_ST声迅_2020.pdf
# [2025-08-28 18:09:03,984] Connection pool is full, discarding connection: static.cninfo.com.cn. Connection pool size: 10
# [2025-08-28 18:09:04,093] Connection pool is full, discarding connection: static.cninfo.com.cn. Connection pool size: 10
# [2025-08-28 18:09:04,223] Connection pool is full, discarding connection: static.cninfo.com.cn. Connection pool size: 10
# [2025-08-28 18:09:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002937_兴瑞科技_2018.pdf
# [2025-08-28 18:09:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002973_侨银股份_2019.pdf
# [2025-08-28 18:09:04,327] Connection pool is full, discarding connection: static.cninfo.com.cn. Connection pool size: 10
# [2025-08-28 18:09:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002961_瑞达期货_2019.pdf
# [2025-08-28 18:09:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002941_新疆交建_2018.pdf
# [2025-08-28 18:09:04,845] Connection pool is full, discarding connection: static.cninfo.com.cn. Connection pool size: 10
# [2025-08-28 18:09:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest/002946_新乳业_2019.pdf
# [2025-08-28 18:09:04] All downloads completed in 109.23s. PDFs saved to: /Users/sam/Desktop/cninfo_output/pdf_prospectus_latest
