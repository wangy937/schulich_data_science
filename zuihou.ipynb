# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os
import pandas as pd
import efinance as ef       # pip install efinance

def main():
    # 1. 定位文件
    in_file  = os.path.expanduser("~/Desktop/行情与分析20250605.xlsx")
    out_file = os.path.expanduser("~/Desktop/正股映射结果.xlsx")

    # 2. 读取原始 Excel
    df_raw = pd.read_excel(in_file, dtype=str)  # 支持 .xlsx/.xls 等格式 :contentReference[oaicite:8]{index=8}

    # 3. 拉取全市场可转债基础信息
    #    包含字段：债券代码、债券名称、正股代码、正股名称、...... :contentReference[oaicite:9]{index=9}
    df_all = ef.bond.get_all_base_info()

    # 4. 清洗字段：提取无后缀的可转债 code 和纯数字正股 code/name
    df_all["bond_code"]  = df_all["债券代码"].astype(str).str.strip()       # e.g. '110059' :contentReference[oaicite:10]{index=10}
    df_all["stock_code"] = df_all["正股代码"].astype(str).str.strip()       # e.g. '600000' :contentReference[oaicite:11]{index=11}
    df_all["stock_name"] = df_all["正股名称"].astype(str).str.strip()       # e.g. '浦发银行' :contentReference[oaicite:12]{index=12}

    # 5. 原表中提取 bond_code（去掉 '.SH'/'.SZ' 后缀）
    df_raw["bond_code"] = df_raw["代码"].str.split(".").str[0]

    # 6. 左合并：把正股信息映射到原表
    df_merged = df_raw.merge(
        df_all[["bond_code", "stock_code", "stock_name"]],
        on="bond_code", how="left"
    )

    # 7. 构造最终列：带后缀的正股代码 + 正股名称
    def add_suffix(code: str) -> str:
        if not isinstance(code, str) or not code.isdigit():
            return ""
        return code + (".SH" if code.startswith(("60","68")) else ".SZ")

    df_merged["正股代码"] = df_merged["stock_code"].apply(add_suffix)
    df_merged["正股名称"] = df_merged["stock_name"].fillna("")

    # 8. 删除中间列并保存到 Excel
    df_final = df_merged.drop(columns=["bond_code", "stock_code", "stock_name"])
    df_final.to_excel(out_file, index=False, engine="openpyxl")  # 支持写入 .xlsx :contentReference[oaicite:13]{index=13}

    print("✅ 正股映射已完成，结果保存在：", out_file)

if __name__ == "__main__":
    main()
# Out:
# ✅ 正股映射已完成，结果保存在： /Users/sam/Desktop/正股映射结果.xlsx

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os
import re
import time
import requests
import openpyxl
import pandas as pd
from typing import List, Dict, Tuple

# —— 参数配置 —— 
YEAR             = 2024
GZH              = "【年报】"

# 输出目录
output_dir = os.path.expanduser("~/Desktop/cninfo_output")
os.makedirs(output_dir, exist_ok=True)

# 正股映射表路径（第一部分脚本生成）
mapping_file = os.path.expanduser("~/Desktop/正股映射结果.xlsx")

# —— 市场/板块控制（保持你原来的设置） —— 
MARKETS = ["szse", "shse"]
PLATES  = ["", "sz", "szmb", "szcy", "sh", "shmb", "shkcp", "bj"]

# —— 过滤词：排除英文/摘要/取消/提示等 —— 
EXCLUDE_KWS = [
    "英文", "英文版", "Annual", "annual", "Summary", "summary",
    "摘要", "摘要版", "年报摘要", "年度报告摘要",
    "取消", "已取消", "披露日期变更", "变更的公告", "提示性公告",
    "H股公告", "B股"
]

# 把各种空格（含全角、NBSP）统一去掉再判断
_SPACE_RE = re.compile(r"[\s\u00A0\u3000]+")
def norm(s: str) -> str:
    return _SPACE_RE.sub("", str(s or "").strip())

# 是否中文“年度报告/年报”
_INCLUDE_AR_PAT = re.compile(r"(年\s*度\s*报\s*告|年\s*报)")
# 更正/修订/更新 权重关键词
_REV_KWS = ["更正", "修订", "更新"]

def is_cn_annual_2024(title: str) -> bool:
    """必须同时符合：含2024；含“年度报告/年报”；且不含排除词"""
    t = norm(title)
    if "2024" not in t:
        return False
    if not _INCLUDE_AR_PAT.search(t):
        return False
    if any(kw in t for kw in EXCLUDE_KWS):
        return False
    return True

# 宽松年份提取：支持“2024 年/年度/年报”等，允许数字与‘年’之间有空格
_YEAR_PATS = [
    re.compile(r"(20\d{2})\s*年?\s*度?\s*报\s*告"),
    re.compile(r"(20\d{2})\s*年?\s*报(?!告)"),
]
def extract_year(title: str) -> str:
    t = norm(title)
    for pat in _YEAR_PATS:
        m = pat.search(t)
        if m:
            return m.group(1)
    # 兜底：标题里有“2024”但没上面两个形式
    m2 = re.search(r"(20\d{2})", t)
    return m2.group(1) if m2 else ""

def ann_weight(it: Dict) -> Tuple[int, int]:
    """权重：更正/修订/更新优先；同级用公告时间最新"""
    title = norm(it.get("announcementTitle", ""))
    w_fix = 10 if any(k in title for k in _REV_KWS) else 0
    try:
        ts = int(it.get("announcementTime", 0))
    except Exception:
        ts = 0
    return (w_fix, ts)

def get_report(page_num: int, date_range: str, column: str, plate: str) -> requests.Response:
    """调用巨潮网历史公告查询接口（保持你的原参数）"""
    url = "http://www.cninfo.com.cn/new/hisAnnouncement/query"
    payload = {
        "pageNum":   page_num,
        "pageSize":  30,
        "column":    column,
        "tabName":   "fulltext",
        "category":  "category_ndbg_szsh",  # 不改你的设置
        "plate":     plate,
        "searchkey": "",
        "secid":     "",
        "trade":     "",
        "seDate":    date_range,
        "sortName":  "code",
        "sortType":  "asc",
        "isHLtitle": "false"
    }
    headers = {
        "Accept":             "*/*",
        "Accept-Language":    "zh-CN,zh;q=0.9",
        "Content-Type":       "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin":             "http://www.cninfo.com.cn",
        "Referer": (
            "http://www.cninfo.com.cn/new/commonUrl/"
            "pageOfSearch?url=disclosure/list/search"
            "&checkedCategory=category_ndbg_szsh"
        ),
        "User-Agent":         "Mozilla/5.0",
        "X-Requested-With":   "XMLHttpRequest"
    }
    return requests.post(url, data=payload, headers=headers, timeout=15)

def download_reports_for_segments(segments: List[str], column: str, plate: str) -> List[Dict]:
    """对给定 market(column)×plate，按分段分页拉取；当场做中文2024年报粗过滤 + 去重"""
    all_ann: List[Dict] = []
    seen = set()  # (secCode, adjunctUrl)
    for date_range in segments:
        try:
            total = get_report(1, date_range, column, plate).json().get("totalpages", 0)
        except Exception:
            continue
        if total <= 0:
            continue

        page = 1
        while page <= total:
            for _ in range(3):  # 重试三次
                try:
                    resp = get_report(page, date_range, column, plate)
                    resp.raise_for_status()
                    anns = resp.json().get("announcements", []) or []
                    # —— 当场粗过滤：必须是“2024 中文年报”，并排除摘要/英文/取消等 —— 
                    for x in anns:
                        title = x.get("announcementTitle", "")
                        if not is_cn_annual_2024(title):
                            continue
                        key = (str(x.get("secCode", "")), str(x.get("adjunctUrl", "")))
                        if key in seen:
                            continue
                        seen.add(key)
                        all_ann.append(x)
                    break
                except Exception:
                    time.sleep(1.5)
            page += 1
    return all_ann

def filter_latest_versions(anns: List[Dict]) -> List[Dict]:
    """同公司同年只保留最新一条：更正/修订/更新 > 时间更近"""
    latest: Dict[Tuple[str, str], Dict] = {}
    for it in anns:
        sec = str(it.get("secCode", ""))
        yr  = extract_year(it.get("announcementTitle", ""))
        if not sec or yr != str(YEAR):
            continue
        key = (sec, yr)
        if key not in latest or ann_weight(it) > ann_weight(latest[key]):
            latest[key] = it
    return list(latest.values())

def collect_all_announcements(year: int) -> List[Dict]:
    """保持你原来的 10 段分段"""
    ny = year + 1
    segments = [
        f"{ny}-01-01~{ny}-04-01", f"{ny}-04-02~{ny}-04-15",
        f"{ny}-04-16~{ny}-04-22", f"{ny}-04-23~{ny}-04-26",
        f"{ny}-04-27~{ny}-04-28", f"{ny}-04-29~{ny}-04-30",
        f"{ny}-05-01~{ny}-07-31", f"{ny}-08-01~{ny}-10-31",
        f"{ny}-11-01~{ny}-11-30", f"{ny}-12-01~{ny}-12-31"
    ]
    raw: List[Dict] = []
    for col in MARKETS:
        for pl in PLATES:
            raw.extend(download_reports_for_segments(segments, col, pl))
    return filter_latest_versions(raw)

def write_selected_excel(anns: List[Dict], year: int) -> None:
    """按映射表顺序输出；没找到就留空"""
    df_map = pd.read_excel(mapping_file, dtype=str).fillna("")
    df_map['sec_no_suf'] = df_map['正股代码'].str.split('.').str[0]

    ann_dict = {
        (str(it.get('secCode', '')),
         extract_year(it.get('announcementTitle', ''))): it
        for it in anns
    }

    wb = openpyxl.Workbook()
    ws = wb.active
    ws.title = f"{year}年报"
    ws.append(["可转债代码","可转债名称","公司代码","公司简称","标题","年份","年报链接"])

    for _, row in df_map.iterrows():
        bond_code = row.get('代码', "")
        bond_name = row.get('名称', "")
        sec       = row.get('sec_no_suf', "")
        comp_name = row.get('正股名称', "")

        it = ann_dict.get((sec, str(year)))
        if it:
            raw_title = re.sub(r"<.*?>","", it.get('announcementTitle','')).replace("：","")
            title = f"《{raw_title}》"
            url   = f"http://static.cninfo.com.cn/{it.get('adjunctUrl','')}"
            yr    = str(year)
        else:
            title = ""; url = ""; yr = ""

        ws.append([bond_code, bond_name, sec, comp_name, title, yr, url])

    dst = os.path.join(output_dir, f"年报链接_{year}_选取公司{GZH}.xlsx")
    wb.save(dst)
    print(f"✅ 已输出：{dst}")

if __name__ == "__main__":
    all_ann = collect_all_announcements(YEAR)
    write_selected_excel(all_ann, YEAR)
    print(f"---- {YEAR} 年下载完成 ----")
# Out:
# ✅ 已输出：/Users/sam/Desktop/cninfo_output/年报链接_2024_选取公司【年报】.xlsx
# ---- 2024 年下载完成 ----

# %%
import pandas as pd
import requests
import os
import re
import logging
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed

logging.basicConfig(level=logging.INFO, format='[%(asctime)s] %(message)s')

def log(msg):
    print(f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] {msg}")

BASE_DIR    = os.path.expanduser("~/Desktop/cninfo_output")
EXCEL_FILE  = os.path.join(BASE_DIR, "年报链接_2024_选取公司【年报】.xlsx")
PDF_DIR     = os.path.join(BASE_DIR, "pdf_reports_2024")
MAX_WORKERS = 16
os.makedirs(PDF_DIR, exist_ok=True)

def norm_code(x: str) -> str:
    """把类似 600000 / 600000.0 / '600000 ' 统一成 6 位字符串"""
    s = str(x).strip()
    s = s.split('.')[0]                 # 去掉 .0
    s = re.sub(r'\D', '', s)            # 去掉非数字
    return s.zfill(6) if s else ""

def is_pdf_response(resp: requests.Response) -> bool:
    ct = (resp.headers.get("Content-Type") or "").lower()
    return ("pdf" in ct) or resp.content.startswith(b"%PDF")

def download_pdf(record):
    code, name, year, url = record
    safe = re.sub(r'[\\/:*?"<>|]', '', f"{code}_{name}_{year}")
    path = os.path.join(PDF_DIR, f"{safe}.pdf")
    if os.path.exists(path) and os.path.getsize(path) > 0:
        log(f"Exists, skip: {path}")
        return
    try:
        resp = requests.get(url, timeout=20, headers={
            "User-Agent": "Mozilla/5.0",
            "Referer": "http://www.cninfo.com.cn/",
        })
        if resp.status_code == 200 and is_pdf_response(resp):
            with open(path, 'wb') as f:
                f.write(resp.content)
            log(f"Downloaded: {path}")
        else:
            log(f"Failed ({resp.status_code}) or not PDF: {url}")
    except Exception as e:
        log(f"Error downloading {url}: {e}")

def main():
    log(f"Reading Excel: {EXCEL_FILE}")
    if not os.path.exists(EXCEL_FILE):
        log("Excel file not found. 请检查路径。")
        return

    # 明确读“2024年报”这张表，列名去空格
    df = pd.read_excel(EXCEL_FILE, sheet_name="2024年报")
    df.columns = [str(c).strip() for c in df.columns]

    # 年份转数字再过滤（避免 2024.0 / '2024 '）
    df["年份"] = pd.to_numeric(df["年份"], errors="coerce")
    df_2024 = df[df["年份"] == 2024].copy()

    # 处理公司代码/简称/链接为空的情况
    df_2024 = df_2024.dropna(subset=["年报链接"])

    records = [
        (norm_code(r["公司代码"]), str(r["公司简称"]).strip(), "2024", str(r["年报链接"]).strip())
        for _, r in df_2024.iterrows()
    ]

    log(f"Found {len(records)} records for 2024.")

    start = datetime.now()
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(download_pdf, rec) for rec in records]
        for _ in as_completed(futures):
            pass
    elapsed = (datetime.now() - start).total_seconds()
    log(f"All downloads completed in {elapsed:.2f}s. PDFs saved to: {PDF_DIR}")

if __name__ == '__main__':
    main()
# Out:
# [2025-08-09 17:45:20] Reading Excel: /Users/sam/Desktop/cninfo_output/年报链接_2024_选取公司【年报】.xlsx
# [2025-08-09 17:45:21] Found 473 records for 2024.
# [2025-08-09 17:45:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600567_山鹰国际_2024.pdf
# [2025-08-09 17:45:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600498_烽火通信_2024.pdf
# [2025-08-09 17:45:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600939_重庆建工_2024.pdf
# [2025-08-09 17:45:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600326_西藏天路_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600903_贵州燃气_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600075_新疆天业_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600029_南方航空_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600496_精工钢构_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600231_凌钢股份_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600438_通威股份_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600521_华海药业_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600885_宏发股份_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600909_华安证券_2024.pdf
# [2025-08-09 17:45:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600370_三房巷_2024.pdf
# [2025-08-09 17:45:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600577_精达股份_2024.pdf
# [2025-08-09 17:45:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600481_双良节能_2024.pdf
# [2025-08-09 17:45:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605222_起帆电缆_2024.pdf
# [2025-08-09 17:45:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600926_杭州银行_2024.pdf
# [2025-08-09 17:45:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605006_山东玻纤_2024.pdf
# [2025-08-09 17:45:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600061_国投资本_2024.pdf
# [2025-08-09 17:45:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600419_天润乳业_2024.pdf
# [2025-08-09 17:45:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605007_五洲特纸_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600888_新疆众和_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600141_兴发集团_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605020_永和股份_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605138_盛泰集团_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605166_聚合顺_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600713_南京医药_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605337_李子园_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600745_闻泰科技_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605358_立昂微_2024.pdf
# [2025-08-09 17:45:24] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605166_聚合顺_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600531_豫光金铅_2024.pdf
# [2025-08-09 17:45:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605189_富春染织_2024.pdf
# [2025-08-09 17:45:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605366_宏柏新材_2024.pdf
# [2025-08-09 17:45:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600933_爱柯迪_2024.pdf
# [2025-08-09 17:45:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601515_东峰集团_2024.pdf
# [2025-08-09 17:45:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605116_奥锐特_2024.pdf
# [2025-08-09 17:45:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601366_利群股份_2024.pdf
# [2025-08-09 17:45:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605077_华康股份_2024.pdf
# [2025-08-09 17:45:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600461_洪城环境_2024.pdf
# [2025-08-09 17:45:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605162_新中港_2024.pdf
# [2025-08-09 17:45:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605228_神通科技_2024.pdf
# [2025-08-09 17:45:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605177_东亚药业_2024.pdf
# [2025-08-09 17:45:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605368_蓝天燃气_2024.pdf
# [2025-08-09 17:45:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605488_福莱新材_2024.pdf
# [2025-08-09 17:45:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605088_冠盛股份_2024.pdf
# [2025-08-09 17:45:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601619_嘉泽新能_2024.pdf
# [2025-08-09 17:45:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600810_神马股份_2024.pdf
# [2025-08-09 17:45:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601231_环旭电子_2024.pdf
# [2025-08-09 17:45:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601609_金田股份_2024.pdf
# [2025-08-09 17:45:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601012_隆基绿能_2024.pdf
# [2025-08-09 17:45:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601633_长城汽车_2024.pdf
# [2025-08-09 17:45:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601963_重庆银行_2024.pdf
# [2025-08-09 17:45:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601016_节能风电_2024.pdf
# [2025-08-09 17:45:28] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601208_东材科技_2024.pdf
# [2025-08-09 17:45:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601229_上海银行_2024.pdf
# [2025-08-09 17:45:29] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601609_金田股份_2024.pdf
# [2025-08-09 17:45:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601636_旗滨集团_2024.pdf
# [2025-08-09 17:45:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601128_常熟银行_2024.pdf
# [2025-08-09 17:45:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601108_财通证券_2024.pdf
# [2025-08-09 17:45:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601865_福莱特_2024.pdf
# [2025-08-09 17:45:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601686_友发集团_2024.pdf
# [2025-08-09 17:45:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/605068_明新旭腾_2024.pdf
# [2025-08-09 17:45:29] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601330_绿色动力_2024.pdf
# [2025-08-09 17:45:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603113_金能科技_2024.pdf
# [2025-08-09 17:45:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601665_齐鲁银行_2024.pdf
# [2025-08-09 17:45:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601139_深圳燃气_2024.pdf
# [2025-08-09 17:45:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603660_苏州科达_2024.pdf
# [2025-08-09 17:45:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603898_好莱客_2024.pdf
# [2025-08-09 17:45:30] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603890_春秋电子_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603089_正裕工业_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603336_宏辉果蔬_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603708_家家悦_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603377_ST东时_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603679_华体科技_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601666_平煤股份_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603131_上海沪工_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601137_博威合金_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601778_晶科科技_2024.pdf
# [2025-08-09 17:45:31] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603912_佳力图_2024.pdf
# [2025-08-09 17:45:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603966_法兰泰克_2024.pdf
# [2025-08-09 17:45:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603233_大参林_2024.pdf
# [2025-08-09 17:45:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601158_重庆水务_2024.pdf
# [2025-08-09 17:45:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603108_润达医疗_2024.pdf
# [2025-08-09 17:45:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603776_永安行_2024.pdf
# [2025-08-09 17:45:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603861_白云电器_2024.pdf
# [2025-08-09 17:45:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603368_柳药集团_2024.pdf
# [2025-08-09 17:45:32] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603538_美诺华_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603979_金诚信_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603976_正川股份_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603225_新凤鸣_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603716_塞力医疗_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603669_灵康药业_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603208_江山欧派_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603685_晨丰科技_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603689_皖天然气_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603579_荣泰健康_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603486_科沃斯_2024.pdf
# [2025-08-09 17:45:33] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603982_泉峰汽车_2024.pdf
# [2025-08-09 17:45:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603995_甬金股份_2024.pdf
# [2025-08-09 17:45:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603605_珀莱雅_2024.pdf
# [2025-08-09 17:45:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603608_天创时尚_2024.pdf
# [2025-08-09 17:45:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603585_苏利股份_2024.pdf
# [2025-08-09 17:45:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603650_彤程新材_2024.pdf
# [2025-08-09 17:45:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603733_仙鹤股份_2024.pdf
# [2025-08-09 17:45:34] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601009_南京银行_2024.pdf
# [2025-08-09 17:45:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603609_禾丰股份_2024.pdf
# [2025-08-09 17:45:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603638_艾迪精密_2024.pdf
# [2025-08-09 17:45:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603186_华正新材_2024.pdf
# [2025-08-09 17:45:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603466_风语筑_2024.pdf
# [2025-08-09 17:45:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603916_苏博特_2024.pdf
# [2025-08-09 17:45:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603112_华翔股份_2024.pdf
# [2025-08-09 17:45:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603810_丰山集团_2024.pdf
# [2025-08-09 17:45:35] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603055_台华新材_2024.pdf
# [2025-08-09 17:45:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603501_豪威集团_2024.pdf
# [2025-08-09 17:45:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603992_松霖科技_2024.pdf
# [2025-08-09 17:45:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603901_永创智能_2024.pdf
# [2025-08-09 17:45:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603681_永冠新材_2024.pdf
# [2025-08-09 17:45:36] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601860_紫金银行_2024.pdf
# [2025-08-09 17:45:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603058_永吉股份_2024.pdf
# [2025-08-09 17:45:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603713_密尔克卫_2024.pdf
# [2025-08-09 17:45:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603568_伟明环保_2024.pdf
# [2025-08-09 17:45:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603867_新化股份_2024.pdf
# [2025-08-09 17:45:37] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603890_春秋电子_2024.pdf
# [2025-08-09 17:45:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603896_寿仙谷_2024.pdf
# [2025-08-09 17:45:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603535_嘉诚国际_2024.pdf
# [2025-08-09 17:45:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603355_莱克电气_2024.pdf
# [2025-08-09 17:45:37] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603757_大元泵业_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603051_鹿山新材_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603176_汇通集团_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603806_福斯特_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603878_武进不锈_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603327_福蓉科技_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603228_景旺电子_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603730_岱美股份_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/601166_兴业银行_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603180_金牌家居_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603477_巨星农牧_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603529_爱玛科技_2024.pdf
# [2025-08-09 17:45:38] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603568_伟明环保_2024.pdf
# [2025-08-09 17:45:38] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603179_新泉股份_2024.pdf
# [2025-08-09 17:45:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603105_芯能科技_2024.pdf
# [2025-08-09 17:45:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603220_中贝通信_2024.pdf
# [2025-08-09 17:45:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603833_欧派家居_2024.pdf
# [2025-08-09 17:45:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603601_再升科技_2024.pdf
# [2025-08-09 17:45:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603018_华设集团_2024.pdf
# [2025-08-09 17:45:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603060_国检集团_2024.pdf
# [2025-08-09 17:45:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603937_丽岛新材_2024.pdf
# [2025-08-09 17:45:39] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603305_旭升集团_2024.pdf
# [2025-08-09 17:45:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603077_和邦生物_2024.pdf
# [2025-08-09 17:45:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603165_荣晟环保_2024.pdf
# [2025-08-09 17:45:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603801_志邦家居_2024.pdf
# [2025-08-09 17:45:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603197_保隆科技_2024.pdf
# [2025-08-09 17:45:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603877_太平鸟_2024.pdf
# [2025-08-09 17:45:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603067_振华股份_2024.pdf
# [2025-08-09 17:45:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603939_益丰药房_2024.pdf
# [2025-08-09 17:45:40] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603289_泰瑞机器_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688059_华锐精密_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603707_健友股份_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603628_清源股份_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688680_海优新材_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688116_天奈科技_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688166_博瑞医药_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603829_洛凯股份_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603799_华友钴业_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603809_豪能股份_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688179_阿拉丁_2024.pdf
# [2025-08-09 17:45:41] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688689_银河微电_2024.pdf
# [2025-08-09 17:45:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688096_京源环保_2024.pdf
# [2025-08-09 17:45:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688026_洁特生物_2024.pdf
# [2025-08-09 17:45:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688321_微芯生物_2024.pdf
# [2025-08-09 17:45:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688001_华兴源创_2024.pdf
# [2025-08-09 17:45:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688388_嘉元科技_2024.pdf
# [2025-08-09 17:45:42] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688595_芯海科技_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603306_华懋科技_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688301_奕瑞科技_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688208_道通科技_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688590_新致软件_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688556_高测股份_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688772_珠海冠宇_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688323_瑞华泰_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688186_广大特材_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688357_建龙微纳_2024.pdf
# [2025-08-09 17:45:43] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688030_山石网科_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688066_航天宏图_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688268_华特气体_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688219_会通股份_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688148_芳源股份_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688223_晶科能源_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688711_宏微科技_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688779_五矿新能_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/603213_镇洋发展_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688350_富淼科技_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688633_星球石墨_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688597_煜邦电力_2024.pdf
# [2025-08-09 17:45:44] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688516_奥特维_2024.pdf
# [2025-08-09 17:45:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688533_上声电子_2024.pdf
# [2025-08-09 17:45:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688135_利扬芯片_2024.pdf
# [2025-08-09 17:45:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688002_睿创微纳_2024.pdf
# [2025-08-09 17:45:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688103_国力股份_2024.pdf
# [2025-08-09 17:45:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688599_天合光能_2024.pdf
# [2025-08-09 17:45:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688311_盟升电子_2024.pdf
# [2025-08-09 17:45:45] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688596_正帆科技_2024.pdf
# [2025-08-09 17:45:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688372_伟测科技_2024.pdf
# [2025-08-09 17:45:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688403_汇成股份_2024.pdf
# [2025-08-09 17:45:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688292_浩瀚深度_2024.pdf
# [2025-08-09 17:45:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688398_赛特新材_2024.pdf
# [2025-08-09 17:45:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688131_皓元医药_2024.pdf
# [2025-08-09 17:45:46] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688019_安集科技_2024.pdf
# [2025-08-09 17:45:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300577_开润股份_2024.pdf
# [2025-08-09 17:45:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300677_英科医疗_2024.pdf
# [2025-08-09 17:45:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300545_联得装备_2024.pdf
# [2025-08-09 17:45:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300190_维尔利_2024.pdf
# [2025-08-09 17:45:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300665_飞鹿股份_2024.pdf[2025-08-09 17:45:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300655_晶瑞电材_2024.pdf
#
# [2025-08-09 17:45:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688239_航宇科技_2024.pdf
# [2025-08-09 17:45:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300231_银信科技_2024.pdf
# [2025-08-09 17:45:47] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300511_雪榕生物_2024.pdf
# [2025-08-09 17:45:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300527_ST应急_2024.pdf
# [2025-08-09 17:45:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300517_海波重科_2024.pdf
# [2025-08-09 17:45:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300424_航新科技_2024.pdf
# [2025-08-09 17:45:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300246_宝莱特_2024.pdf
# [2025-08-09 17:45:48] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300729_乐歌股份_2024.pdf
# [2025-08-09 17:45:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300608_思特奇_2024.pdf
# [2025-08-09 17:45:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300569_天能重工_2024.pdf
# [2025-08-09 17:45:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688678_福立旺_2024.pdf
# [2025-08-09 17:45:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300707_威唐工业_2024.pdf
# [2025-08-09 17:45:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300429_强力新材_2024.pdf
# [2025-08-09 17:45:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300196_长海股份_2024.pdf
# [2025-08-09 17:45:49] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300265_通光线缆_2024.pdf
# [2025-08-09 17:45:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300298_三诺生物_2024.pdf
# [2025-08-09 17:45:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300021_大禹节水_2024.pdf
# [2025-08-09 17:45:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300498_温氏股份_2024.pdf
# [2025-08-09 17:45:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300651_金陵体育_2024.pdf
# [2025-08-09 17:45:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300739_明阳电路_2024.pdf
# [2025-08-09 17:45:50] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300482_万孚生物_2024.pdf
# [2025-08-09 17:45:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300253_卫宁健康_2024.pdf
# [2025-08-09 17:45:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300003_乐普医疗_2024.pdf
# [2025-08-09 17:45:51] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300151_昌红科技_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300529_健帆生物_2024.pdf
# [2025-08-09 17:45:52] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300655_晶瑞电材_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300332_天壕能源_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300775_三角防务_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300243_瑞丰高材_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300601_康泰生物_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300776_帝尔激光_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300613_富瀚微_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300798_锦鸡股份_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300483_首华燃气_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300040_九洲集团_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300112_万讯自控_2024.pdf
# [2025-08-09 17:45:52] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300057_万顺新材_2024.pdf
# [2025-08-09 17:45:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688106_金宏气体_2024.pdf
# [2025-08-09 17:45:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300263_隆华科技_2024.pdf
# [2025-08-09 17:45:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300016_北陆药业_2024.pdf
# [2025-08-09 17:45:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300732_设研院_2024.pdf
# [2025-08-09 17:45:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300673_佩蒂股份_2024.pdf
# [2025-08-09 17:45:53] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300933_中辰股份_2024.pdf
# [2025-08-09 17:45:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300738_奥飞数据_2024.pdf
# [2025-08-09 17:45:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300869_康泰医学_2024.pdf
# [2025-08-09 17:45:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300853_申昊科技_2024.pdf
# [2025-08-09 17:45:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300839_博汇股份_2024.pdf
# [2025-08-09 17:45:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300894_火星人_2024.pdf
# [2025-08-09 17:45:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300791_仙乐健康_2024.pdf
# [2025-08-09 17:45:54] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300663_科蓝软件_2024.pdf
# [2025-08-09 17:45:55] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300283_温州宏丰_2024.pdf
# [2025-08-09 17:45:55] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301002_崧盛股份_2024.pdf
# [2025-08-09 17:45:55] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300305_裕兴股份_2024.pdf
# [2025-08-09 17:45:55] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300037_新宙邦_2024.pdf
# [2025-08-09 17:45:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300850_新强联_2024.pdf
# [2025-08-09 17:45:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301040_中环海陆_2024.pdf
# [2025-08-09 17:45:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300992_泰福泵业_2024.pdf
# [2025-08-09 17:45:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300486_东杰智能_2024.pdf
# [2025-08-09 17:45:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300041_回天新材_2024.pdf
# [2025-08-09 17:45:56] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300876_蒙泰高新_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300258_精锻科技_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/688589_力合微_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300966_共同药业_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/600000_浦发银行_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300891_惠云钛业_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300567_精测电子_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300605_恒锋信息_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300837_浙矿股份_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301017_漱玉平民_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300900_广联航空_2024.pdf
# [2025-08-09 17:45:57] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300185_通裕重工_2024.pdf
# [2025-08-09 17:45:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300614_百川畅银_2024.pdf
# [2025-08-09 17:45:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300556_丝路视觉_2024.pdf
# [2025-08-09 17:45:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300224_正海磁材_2024.pdf
# [2025-08-09 17:45:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301186_超达装备_2024.pdf
# [2025-08-09 17:45:58] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300406_九强生物_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300787_海能实业_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300826_测绘股份_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301046_能辉科技_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300856_科思股份_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300501_海顺新材_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300779_惠城环保_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300401_花园生物_2024.pdf
# [2025-08-09 17:45:59] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300739_明阳电路_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301098_金埔园林_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300480_光力科技_2024.pdf
# [2025-08-09 17:45:59] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300487_蓝晓科技_2024.pdf
# [2025-08-09 17:46:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300872_天阳科技_2024.pdf
# [2025-08-09 17:46:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300645_正元智慧_2024.pdf
# [2025-08-09 17:46:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300452_山河药辅_2024.pdf
# [2025-08-09 17:46:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300829_金丹科技_2024.pdf
# [2025-08-09 17:46:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300272_开能健康_2024.pdf
# [2025-08-09 17:46:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300692_中环环保_2024.pdf
# [2025-08-09 17:46:00] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300986_志特新材_2024.pdf
# [2025-08-09 17:46:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301127_武汉天源_2024.pdf
# [2025-08-09 17:46:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300454_深信服_2024.pdf
# [2025-08-09 17:46:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300121_阳谷华泰_2024.pdf
# [2025-08-09 17:46:01] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301022_海泰科_2024.pdf
# [2025-08-09 17:46:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300852_四会富仕_2024.pdf
# [2025-08-09 17:46:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301268_铭利达_2024.pdf
# [2025-08-09 17:46:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300644_南京聚隆_2024.pdf
# [2025-08-09 17:46:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301188_力诺药包_2024.pdf
# [2025-08-09 17:46:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301015_百洋医药_2024.pdf
# [2025-08-09 17:46:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300926_博俊科技_2024.pdf
# [2025-08-09 17:46:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300942_易瑞生物_2024.pdf
# [2025-08-09 17:46:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300740_水羊股份_2024.pdf
# [2025-08-09 17:46:02] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300239_东宝生物_2024.pdf
# [2025-08-09 17:46:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301133_金钟股份_2024.pdf
# [2025-08-09 17:46:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300938_信测标准_2024.pdf
# [2025-08-09 17:46:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300705_九典制药_2024.pdf
# [2025-08-09 17:46:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300890_翔丰华_2024.pdf
# [2025-08-09 17:46:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300911_亿田智能_2024.pdf
# [2025-08-09 17:46:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301069_凯盛新材_2024.pdf
# [2025-08-09 17:46:03] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300948_冠中生态_2024.pdf
# [2025-08-09 17:46:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300725_药石科技_2024.pdf
# [2025-08-09 17:46:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300870_欧陆通_2024.pdf
# [2025-08-09 17:46:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301193_家联科技_2024.pdf
# [2025-08-09 17:46:04] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300062_中能电气_2024.pdf
# [2025-08-09 17:46:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300967_晓鸣股份_2024.pdf
# [2025-08-09 17:46:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301266_宇邦新材_2024.pdf
# [2025-08-09 17:46:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301008_宏昌科技_2024.pdf
# [2025-08-09 17:46:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300488_恒锋工具_2024.pdf
# [2025-08-09 17:46:05] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300893_松原安全_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301131_聚赛龙_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300830_金现代_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301081_严牌股份_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301004_嘉益股份_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300358_楚天科技_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300428_立中集团_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300793_佳禾智能_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301229_纽泰格_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300681_英搏尔_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301053_远信工业_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300973_立高食品_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300952_恒辉安防_2024.pdf
# [2025-08-09 17:46:06] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300351_永贵电器_2024.pdf
# [2025-08-09 17:46:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301235_华康洁净_2024.pdf
# [2025-08-09 17:46:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000726_鲁泰A_2024.pdf
# [2025-08-09 17:46:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300337_银邦股份_2024.pdf
# [2025-08-09 17:46:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300553_集智股份_2024.pdf
# [2025-08-09 17:46:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301062_上海艾录_2024.pdf
# [2025-08-09 17:46:07] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000761_本钢板材_2024.pdf
# [2025-08-09 17:46:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300014_亿纬锂能_2024.pdf
# [2025-08-09 17:46:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000411_英特集团_2024.pdf[2025-08-09 17:46:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300737_科顺股份_2024.pdf
#
# [2025-08-09 17:46:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000876_新希望_2024.pdf
# [2025-08-09 17:46:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000688_国城矿业_2024.pdf
# [2025-08-09 17:46:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000902_新洋丰_2024.pdf
# [2025-08-09 17:46:08] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000401_冀东水泥_2024.pdf
# [2025-08-09 17:46:09] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000060_中金岭南_2024.pdf
# [2025-08-09 17:46:09] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000967_盈峰环境_2024.pdf
# [2025-08-09 17:46:09] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002822_ST中装_2024.pdf
# [2025-08-09 17:46:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002969_嘉美包装_2024.pdf
# [2025-08-09 17:46:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002887_绿茵生态_2024.pdf
# [2025-08-09 17:46:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/301216_万凯新材_2024.pdf
# [2025-08-09 17:46:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000823_超声电子_2024.pdf
# [2025-08-09 17:46:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000789_万年青_2024.pdf
# [2025-08-09 17:46:10] Exists, skip: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000876_新希望_2024.pdf
# [2025-08-09 17:46:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002225_濮耐股份_2024.pdf
# [2025-08-09 17:46:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002126_银轮股份_2024.pdf
# [2025-08-09 17:46:10] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000582_北部湾港_2024.pdf
# [2025-08-09 17:46:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002918_蒙娜丽莎_2024.pdf
# [2025-08-09 17:46:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002895_川恒股份_2024.pdf
# [2025-08-09 17:46:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002984_森麒麟_2024.pdf
# [2025-08-09 17:46:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002568_百润股份_2024.pdf
# [2025-08-09 17:46:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002049_紫光国微_2024.pdf
# [2025-08-09 17:46:11] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002714_牧原股份_2024.pdf
# [2025-08-09 17:46:12] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002534_西子洁能_2024.pdf
# [2025-08-09 17:46:12] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002989_中天精装_2024.pdf
# [2025-08-09 17:46:12] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000723_美锦能源_2024.pdf
# [2025-08-09 17:46:12] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002753_永东股份_2024.pdf
# [2025-08-09 17:46:12] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002091_江苏国泰_2024.pdf
# [2025-08-09 17:46:12] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002988_豪美新材_2024.pdf
# [2025-08-09 17:46:13] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002982_湘佳股份_2024.pdf
# [2025-08-09 17:46:13] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002381_双箭股份_2024.pdf
# [2025-08-09 17:46:13] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/001203_大中矿业_2024.pdf
# [2025-08-09 17:46:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/003009_中天火箭_2024.pdf
# [2025-08-09 17:46:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002959_小熊电器_2024.pdf
# [2025-08-09 17:46:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000708_中信特钢_2024.pdf
# [2025-08-09 17:46:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002850_科达利_2024.pdf
# [2025-08-09 17:46:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002798_帝欧家居_2024.pdf
# [2025-08-09 17:46:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002996_顺博合金_2024.pdf
# [2025-08-09 17:46:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/300054_鼎龙股份_2024.pdf
# [2025-08-09 17:46:14] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002709_天赐材料_2024.pdf
# [2025-08-09 17:46:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002455_百川股份_2024.pdf
# [2025-08-09 17:46:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002998_优彩资源_2024.pdf
# [2025-08-09 17:46:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000703_恒逸石化_2024.pdf
# [2025-08-09 17:46:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002645_华宏科技_2024.pdf
# [2025-08-09 17:46:15] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/003004_ST声迅_2024.pdf
# [2025-08-09 17:46:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002430_杭氧股份_2024.pdf
# [2025-08-09 17:46:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002398_垒知集团_2024.pdf
# [2025-08-09 17:46:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002540_亚太科技_2024.pdf
# [2025-08-09 17:46:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/001212_中旗新材_2024.pdf
# [2025-08-09 17:46:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/003043_华亚智能_2024.pdf
# [2025-08-09 17:46:16] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000498_山东路桥_2024.pdf
# [2025-08-09 17:46:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002937_兴瑞科技_2024.pdf
# [2025-08-09 17:46:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002237_恒邦股份_2024.pdf
# [2025-08-09 17:46:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002810_山东赫达_2024.pdf
# [2025-08-09 17:46:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/001288_运机集团_2024.pdf
# [2025-08-09 17:46:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000528_柳工_2024.pdf
# [2025-08-09 17:46:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/003036_泰坦股份_2024.pdf
# [2025-08-09 17:46:17] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002833_弘亚数控_2024.pdf
# [2025-08-09 17:46:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002698_博实股份_2024.pdf
# [2025-08-09 17:46:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/001269_欧晶科技_2024.pdf
# [2025-08-09 17:46:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/001317_三羊马_2024.pdf
# [2025-08-09 17:46:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002120_韵达股份_2024.pdf
# [2025-08-09 17:46:18] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002871_伟隆股份_2024.pdf
# [2025-08-09 17:46:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002809_红墙股份_2024.pdf
# [2025-08-09 17:46:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/001283_豪鹏科技_2024.pdf
# [2025-08-09 17:46:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002459_晶澳科技_2024.pdf
# [2025-08-09 17:46:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002442_龙星科技_2024.pdf
# [2025-08-09 17:46:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000591_太阳能_2024.pdf
# [2025-08-09 17:46:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002598_山东章鼓_2024.pdf
# [2025-08-09 17:46:19] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002605_姚记科技_2024.pdf
# [2025-08-09 17:46:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002228_合兴包装_2024.pdf
# [2025-08-09 17:46:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002614_奥佳华_2024.pdf
# [2025-08-09 17:46:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000703_恒逸石化_2024.pdf
# [2025-08-09 17:46:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002806_华锋股份_2024.pdf
# [2025-08-09 17:46:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002036_联创电子_2024.pdf
# [2025-08-09 17:46:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002203_海亮股份_2024.pdf
# [2025-08-09 17:46:20] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/001205_盛航股份_2024.pdf
# [2025-08-09 17:46:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002961_瑞达期货_2024.pdf
# [2025-08-09 17:46:21] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002812_恩捷股份_2024.pdf
# [2025-08-09 17:46:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002174_游族网络_2024.pdf
# [2025-08-09 17:46:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002921_联诚精密_2024.pdf
# [2025-08-09 17:46:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002382_蓝帆医疗_2024.pdf
# [2025-08-09 17:46:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002761_浙江建投_2024.pdf
# [2025-08-09 17:46:22] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002171_楚江新材_2024.pdf
# [2025-08-09 17:46:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002722_物产金轮_2024.pdf
# [2025-08-09 17:46:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000552_甘肃能化_2024.pdf
# [2025-08-09 17:46:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002877_智能自控_2024.pdf
# [2025-08-09 17:46:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002022_科华生物_2024.pdf
# [2025-08-09 17:46:23] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002616_长青集团_2024.pdf
# [2025-08-09 17:46:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002436_兴森科技_2024.pdf
# [2025-08-09 17:46:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002135_东南网架_2024.pdf
# [2025-08-09 17:46:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002949_华阳国际_2024.pdf
# [2025-08-09 17:46:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002557_洽洽食品_2024.pdf
# [2025-08-09 17:46:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002775_文科股份_2024.pdf
# [2025-08-09 17:46:24] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002891_中宠股份_2024.pdf
# [2025-08-09 17:46:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002475_立讯精密_2024.pdf
# [2025-08-09 17:46:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002408_齐翔腾达_2024.pdf
# [2025-08-09 17:46:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002815_崇达技术_2024.pdf
# [2025-08-09 17:46:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002930_宏川智慧_2024.pdf
# [2025-08-09 17:46:25] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002941_新疆交建_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002287_奇正藏药_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002111_威海广泰_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002958_青农商行_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002034_旺能环境_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002067_景兴纸业_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002541_鸿路钢构_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002973_侨银股份_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002734_利民股份_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002946_新乳业_2024.pdf
# [2025-08-09 17:46:26] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002859_洁美科技_2024.pdf
# [2025-08-09 17:46:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002600_领益智造_2024.pdf
# [2025-08-09 17:46:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/000301_东方盛虹_2024.pdf
# [2025-08-09 17:46:27] Downloaded: /Users/sam/Desktop/cninfo_output/pdf_reports_2024/002726_龙大美食_2024.pdf
# [2025-08-09 17:46:27] All downloads completed in 66.55s. PDFs saved to: /Users/sam/Desktop/cninfo_output/pdf_reports_2024
