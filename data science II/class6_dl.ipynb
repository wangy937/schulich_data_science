# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /Users/sam/Library/Python/3.9/lib/python/site-packages (2.18.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (5.29.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: packaging in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: optree in /Users/sam/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (0.13.1)
# Requirement already satisfied: namex in /Users/sam/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: rich in /Users/sam/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.20)
# Requirement already satisfied: markdown>=2.6.8 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0  # Normalize pixel values
y_train, y_test = to_categorical(y_train), to_categorical(y_test)  # One-hot encode labels

# Create notebook sections with markdown for structure
notebook_content = """
# MNIST Deep Learning Model Examples

In this notebook, we explore different neural network architectures to classify the MNIST dataset of handwritten digits.

## Step 1: Load and Preprocess Data
We load the MNIST dataset from Keras and normalize it so that pixel values are between 0 and 1. We also one-hot encode the labels.

```python
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0  # Normalize pixel values
y_train, y_test = to_categorical(y_train), to_categorical(y_test)  # One-hot encode labels
"""
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

model1 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history1 = model1.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# /Users/sam/Library/Python/3.9/lib/python/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 628us/step - accuracy: 0.8754 - loss: 0.4356 - val_accuracy: 0.9596 - val_loss: 0.1415
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 589us/step - accuracy: 0.9651 - loss: 0.1209 - val_accuracy: 0.9694 - val_loss: 0.0957
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 587us/step - accuracy: 0.9770 - loss: 0.0790 - val_accuracy: 0.9758 - val_loss: 0.0813
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 592us/step - accuracy: 0.9818 - loss: 0.0606 - val_accuracy: 0.9746 - val_loss: 0.0763
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step - accuracy: 0.9858 - loss: 0.0452 - val_accuracy: 0.9740 - val_loss: 0.0819

# %%
model2 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='relu'),
    Dense(128, activation='sigmoid'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history2 = model2.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8691 - loss: 0.4609 - val_accuracy: 0.9614 - val_loss: 0.1209
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 953us/step - accuracy: 0.9699 - loss: 0.0982 - val_accuracy: 0.9719 - val_loss: 0.0894
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 861us/step - accuracy: 0.9811 - loss: 0.0616 - val_accuracy: 0.9760 - val_loss: 0.0778
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 889us/step - accuracy: 0.9869 - loss: 0.0422 - val_accuracy: 0.9790 - val_loss: 0.0692
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 866us/step - accuracy: 0.9896 - loss: 0.0331 - val_accuracy: 0.9780 - val_loss: 0.0761

# %%
from tensorflow.keras.layers import Dropout

model3 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(256, activation='tanh'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history3 = model3.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8372 - loss: 0.5121 - val_accuracy: 0.9592 - val_loss: 0.1342
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9430 - loss: 0.1869 - val_accuracy: 0.9692 - val_loss: 0.1025
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9525 - loss: 0.1554 - val_accuracy: 0.9732 - val_loss: 0.0902
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9607 - loss: 0.1279 - val_accuracy: 0.9747 - val_loss: 0.0854
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9654 - loss: 0.1126 - val_accuracy: 0.9753 - val_loss: 0.0861

# %%
model4 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='tanh'),
    Dense(128, activation='sigmoid'),
    Dense(10, activation='softmax')
])

model4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history4 = model4.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8735 - loss: 0.4618 - val_accuracy: 0.9540 - val_loss: 0.1551
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9636 - loss: 0.1220 - val_accuracy: 0.9718 - val_loss: 0.0933
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9788 - loss: 0.0710 - val_accuracy: 0.9736 - val_loss: 0.0915
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9847 - loss: 0.0508 - val_accuracy: 0.9776 - val_loss: 0.0739
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9905 - loss: 0.0325 - val_accuracy: 0.9794 - val_loss: 0.0650

# %%
import matplotlib.pyplot as plt

# Function to plot accuracy and loss for each model
def plot_metrics(histories, model_names):
    plt.figure(figsize=(12, 5))
    
    # Plot accuracy
    plt.subplot(1, 2, 1)
    for history, name in zip(histories, model_names):
        plt.plot(history.history['accuracy'], label=f'{name} - Train')
        plt.plot(history.history['val_accuracy'], linestyle="--", label=f'{name} - Validation')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Plot loss
    plt.subplot(1, 2, 2)
    for history, name in zip(histories, model_names):
        plt.plot(history.history['loss'], label=f'{name} - Train')
        plt.plot(history.history['val_loss'], linestyle="--", label=f'{name} - Validation')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# List of histories and names for each model
histories = [history1, history2, history3, history4]
model_names = ['Simple Model', 'Multi-Layer Model', 'Dropout Model', 'Activation Experiment Model']

# Plot the metrics
plot_metrics(histories, model_names)

# %%
predictions = model1.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step

# %%
predicted_classes = predictions.argmax(axis=1)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Select an image from the test set
index = 0  # Change this index to view different images
image = X_test[index]

# Make a prediction for the selected image
prediction = model1.predict(np.expand_dims(image, axis=0))
predicted_class = prediction.argmax()

# Plot the image with the prediction
plt.imshow(image, cmap='gray')
plt.title(f"Predicted Class: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# True labels from the test set
true_classes = y_test.argmax(axis=1)

# Calculate accuracy
accuracy = np.mean(predicted_classes == true_classes)
print(f"Test Set Accuracy: {accuracy * 100:.2f}%")
# Out:
# Test Set Accuracy: 97.40%
